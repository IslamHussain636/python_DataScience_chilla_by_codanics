# %% [markdown]
# # Pandas
# ### OpenSource
# - (panel data analysis)
# - 2008 -2009 open source
# - 2012 python for data analysis
# - 2015 numfocus soponserd project
# - 2018 first in core development
#   ### Why ?
#   - Easy for analysis and manipulation
#   #### Data Manipulation
#   - consistent, project related data... simply clean data
#   - Data Filter
#   - Ignore delete
#   - Combining datasets
#   - Spliting data
#   - Find missing data
#   - Duplicate remove or find out.
#   - Scraping Image data
#   #### Data Analysis
#   - Graphs
#   - Reports
#   - Presents

# %% [markdown]
# ## Types of data Analysis
# - Descriptive
# - Dignostic
# - Predictive
# - Prescriptive

# %% [markdown]
# Pandas  | MS Excel  |
# ---------|----------|
#  Data Frames | Worksheet |
#  Series | Colunms |
#  row | row|
#  Nan | empty cell
#  index|Cell number

# %% [markdown]
# > practice on pandas

# %% [markdown]
# #### Install the pandas using pip command
# - pip install panda for windows
# -
# - pip3 install panda for mac

# %%
import numpy as np

# %%
import pandas as pd

# %%
# Creation 
s=pd.Series([1,3,np.nan,5,7,8,9])
s
# Out:
# 0    1.0
# 1    3.0
# 2    NaN
# 3    5.0
# 4    7.0
# 5    8.0
# 6    9.0
# dtype: float64

# %%
dates=pd.date_range('20220101',periods=6)
dates
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df= pd.DataFrame(np.random.rand(6,4),index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2022-01-01  0.626449  0.159775  0.391022  0.551089
# 2022-01-02  0.247976  0.205127  0.658375  0.243965
# 2022-01-03  0.982937  0.741461  0.135687  0.991404
# 2022-01-04  0.387686  0.790554  0.275625  0.639088
# 2022-01-05  0.325179  0.664340  0.927564  0.486577
# 2022-01-06  0.880333  0.566927  0.634396  0.531149

# %%
df= pd.DataFrame(np.random.rand(6,4),index=dates, columns=list('DEFG'))
df
# Out:
#                    D         E         F         G
# 2022-01-01  0.350686  0.949742  0.796472  0.682540
# 2022-01-02  0.458201  0.109659  0.308599  0.097521
# 2022-01-03  0.484906  0.743152  0.148366  0.696376
# 2022-01-04  0.165417  0.263410  0.201963  0.993756
# 2022-01-05  0.402928  0.907095  0.194991  0.802743
# 2022-01-06  0.123166  0.833257  0.702628  0.697966

# %%
df2=pd.DataFrame({"A": 1.0,
 "B":pd.Timestamp('20220111'),
 "C":pd.Series(1,index=list(range(4)),dtype='float32'), 
 "D":np.array([3]* 4,dtype="int32"), 
 "E":pd.Categorical(['girl','woman','girl','woman']),
 "F":'females',})
df2
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.head()
# Out:
#      A          B    C  D      E        F
# 0  1.0 2022-01-11  1.0  3   girl  females
# 1  1.0 2022-01-11  1.0  3  woman  females
# 2  1.0 2022-01-11  1.0  3   girl  females
# 3  1.0 2022-01-11  1.0  3  woman  females

# %%
df2.tail(2)
# Out:
#      A          B    C  D      E        F
# 2  1.0 2022-01-11  1.0  3   girl  females
# 3  1.0 2022-01-11  1.0  3  woman  females

# %%
df2.head(2)
# Out:
#      A          B    C  D      E        F
# 0  1.0 2022-01-11  1.0  3   girl  females
# 1  1.0 2022-01-11  1.0  3  woman  females

# %%
df2.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2022-01-11 00:00:00'), 1.0, 3, 'girl', 'females'],
#        [1.0, Timestamp('2022-01-11 00:00:00'), 1.0, 3, 'woman',
#         'females'],
#        [1.0, Timestamp('2022-01-11 00:00:00'), 1.0, 3, 'girl', 'females'],
#        [1.0, Timestamp('2022-01-11 00:00:00'), 1.0, 3, 'woman',
#         'females']], dtype=object)

# %%
df.to_numpy()
# Out:
# array([[0.350686  , 0.94974168, 0.79647164, 0.68254015],
#        [0.45820114, 0.10965889, 0.30859908, 0.09752103],
#        [0.48490567, 0.74315153, 0.14836563, 0.6963761 ],
#        [0.16541665, 0.26341002, 0.20196263, 0.99375586],
#        [0.40292782, 0.90709497, 0.19499128, 0.80274294],
#        [0.12316554, 0.83325677, 0.70262814, 0.69796646]])

# %%
df.describe()
# Out:
#               D         E         F         G
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.330884  0.634386  0.392170  0.661817
# std    0.152342  0.357256  0.283312  0.300468
# min    0.123166  0.109659  0.148366  0.097521
# 25%    0.211734  0.383345  0.196734  0.685999
# 50%    0.376807  0.788204  0.255281  0.697171
# 75%    0.444383  0.888635  0.604121  0.776549
# max    0.484906  0.949742  0.796472  0.993756

# %%
df.transpose()
# Out:
#    2022-01-01  2022-01-02  2022-01-03  2022-01-04  2022-01-05  2022-01-06
# D    0.350686    0.458201    0.484906    0.165417    0.402928    0.123166
# E    0.949742    0.109659    0.743152    0.263410    0.907095    0.833257
# F    0.796472    0.308599    0.148366    0.201963    0.194991    0.702628
# G    0.682540    0.097521    0.696376    0.993756    0.802743    0.697966

# %%
df.T
# Out:
#    2022-01-01  2022-01-02  2022-01-03  2022-01-04  2022-01-05  2022-01-06
# D    0.350686    0.458201    0.484906    0.165417    0.402928    0.123166
# E    0.949742    0.109659    0.743152    0.263410    0.907095    0.833257
# F    0.796472    0.308599    0.148366    0.201963    0.194991    0.702628
# G    0.682540    0.097521    0.696376    0.993756    0.802743    0.697966

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    G         F         E         D
# 2022-01-01  0.682540  0.796472  0.949742  0.350686
# 2022-01-02  0.097521  0.308599  0.109659  0.458201
# 2022-01-03  0.696376  0.148366  0.743152  0.484906
# 2022-01-04  0.993756  0.201963  0.263410  0.165417
# 2022-01-05  0.802743  0.194991  0.907095  0.402928
# 2022-01-06  0.697966  0.702628  0.833257  0.123166

# %%
df.sort_index(axis=1, ascending=True)
# Out:
#                    D         E         F         G
# 2022-01-01  0.350686  0.949742  0.796472  0.682540
# 2022-01-02  0.458201  0.109659  0.308599  0.097521
# 2022-01-03  0.484906  0.743152  0.148366  0.696376
# 2022-01-04  0.165417  0.263410  0.201963  0.993756
# 2022-01-05  0.402928  0.907095  0.194991  0.802743
# 2022-01-06  0.123166  0.833257  0.702628  0.697966

# %%
df["D"]
# Out:
# 2022-01-01    0.350686
# 2022-01-02    0.458201
# 2022-01-03    0.484906
# 2022-01-04    0.165417
# 2022-01-05    0.402928
# 2022-01-06    0.123166
# Freq: D, Name: D, dtype: float64

# %%
df2["A"]
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# Name: A, dtype: float64

# %%
#row wise selection 
df[0:]
# Out:
#                    D         E         F         G
# 2022-01-01  0.350686  0.949742  0.796472  0.682540
# 2022-01-02  0.458201  0.109659  0.308599  0.097521
# 2022-01-03  0.484906  0.743152  0.148366  0.696376
# 2022-01-04  0.165417  0.263410  0.201963  0.993756
# 2022-01-05  0.402928  0.907095  0.194991  0.802743
# 2022-01-06  0.123166  0.833257  0.702628  0.697966

# %%
df[2:3]
# Out:
#                    D         E         F         G
# 2022-01-03  0.484906  0.743152  0.148366  0.696376

# %%
df.loc[dates[0]]
# Out:
# D    0.350686
# E    0.949742
# F    0.796472
# G    0.682540
# Name: 2022-01-01 00:00:00, dtype: float64

# %%
df.loc[dates[1]]
# Out:
# D    0.458201
# E    0.109659
# F    0.308599
# G    0.097521
# Name: 2022-01-02 00:00:00, dtype: float64

# %%
df2.loc[:,["A","B"]]
# Out:
#      A          B
# 0  1.0 2022-01-11
# 1  1.0 2022-01-11
# 2  1.0 2022-01-11
# 3  1.0 2022-01-11

# %%
df.iloc[0:2, 0:3]
# Out:
#                    D         E         F
# 2022-01-01  0.350686  0.949742  0.796472
# 2022-01-02  0.458201  0.109659  0.308599

# %%
df.iloc[:,0:2]
# Out:
#                    D         E
# 2022-01-01  0.350686  0.949742
# 2022-01-02  0.458201  0.109659
# 2022-01-03  0.484906  0.743152
# 2022-01-04  0.165417  0.263410
# 2022-01-05  0.402928  0.907095
# 2022-01-06  0.123166  0.833257

# %%
df[df["D"]>1.2]
# Out:
# Empty DataFrame
# Columns: [D, E, F, G]
# Index: []

# %%
df[df>0]
# Out:
#                    D         E         F         G
# 2022-01-01  0.350686  0.949742  0.796472  0.682540
# 2022-01-02  0.458201  0.109659  0.308599  0.097521
# 2022-01-03  0.484906  0.743152  0.148366  0.696376
# 2022-01-04  0.165417  0.263410  0.201963  0.993756
# 2022-01-05  0.402928  0.907095  0.194991  0.802743
# 2022-01-06  0.123166  0.833257  0.702628  0.697966

# %%
#isin method 
df2.copy()
# Out:
#      A          B    C  D      E        F
# 0  1.0 2022-01-11  1.0  3   girl  females
# 1  1.0 2022-01-11  1.0  3  woman  females
# 2  1.0 2022-01-11  1.0  3   girl  females
# 3  1.0 2022-01-11  1.0  3  woman  females

# %%
df2.copy()
df2["G"]=["one",'one','two','three']
df2
# Out:
#      A          B    C  D      E        F      G
# 0  1.0 2022-01-11  1.0  3   girl  females    one
# 1  1.0 2022-01-11  1.0  3  woman  females    one
# 2  1.0 2022-01-11  1.0  3   girl  females    two
# 3  1.0 2022-01-11  1.0  3  woman  females  three

# %%
df2['mean']=[1,2,3,4]
df2
# Out:
#      A          B    C  D      E        F      G  mean
# 0  1.0 2022-01-11  1.0  3   girl  females    one     1
# 1  1.0 2022-01-11  1.0  3  woman  females    one     2
# 2  1.0 2022-01-11  1.0  3   girl  females    two     3
# 3  1.0 2022-01-11  1.0  3  woman  females  three     4

# %%
df['mean']=[1,2,3,4,5,6]
df
# Out:
#                    D         E         F         G  mean
# 2022-01-01  0.350686  0.949742  0.796472  0.682540     1
# 2022-01-02  0.458201  0.109659  0.308599  0.097521     2
# 2022-01-03  0.484906  0.743152  0.148366  0.696376     3
# 2022-01-04  0.165417  0.263410  0.201963  0.993756     4
# 2022-01-05  0.402928  0.907095  0.194991  0.802743     5
# 2022-01-06  0.123166  0.833257  0.702628  0.697966     6

# %%
df['new']=[1,2,3,4,5,6]
df
# Out:
#                    D         E         F         G  mean  new
# 2022-01-01  0.350686  0.949742  0.796472  0.682540     1    1
# 2022-01-02  0.458201  0.109659  0.308599  0.097521     2    2
# 2022-01-03  0.484906  0.743152  0.148366  0.696376     3    3
# 2022-01-04  0.165417  0.263410  0.201963  0.993756     4    4
# 2022-01-05  0.402928  0.907095  0.194991  0.802743     5    5
# 2022-01-06  0.123166  0.833257  0.702628  0.697966     6    6

# %%
df['meann']=df.mean(axis=1)
df
# Out:
#                    D         E         F         G  mean  new     meann
# 2022-01-01  0.350686  0.949742  0.796472  0.682540     1    1  0.796573
# 2022-01-02  0.458201  0.109659  0.308599  0.097521     2    2  0.828997
# 2022-01-03  0.484906  0.743152  0.148366  0.696376     3    3  1.345466
# 2022-01-04  0.165417  0.263410  0.201963  0.993756     4    4  1.604091
# 2022-01-05  0.402928  0.907095  0.194991  0.802743     5    5  2.051293
# 2022-01-06  0.123166  0.833257  0.702628  0.697966     6    6  2.392836

# %%
import pandas as pd
import random
 
# read the data from the downloaded CSV file.
data = pd.read_csv('https://s3-eu-west-1.amazonaws.com/shanebucket/downloads/uk-500.csv')
# set a numeric id for use as an index for examples.
data['id'] = [random.randint(0,1000) for x in range(data.shape[0])]
 
data.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# 1  01714-737668    evan.zigomalas@gmail.com
# 2  01935-821636  france.andrade@hotmail.com
# 3  01302-601380         ulysses@hotmail.com
# 4  01290-367248   tyisha.veness@hotmail.com
#
#                                     web   id
# 0  http://www.alandrosenburgcpapc.co.uk  720
# 1     http://www.capgeminiamerica.co.uk  502
# 2      http://www.elliottjohnwesq.co.uk  929
# 3          http://www.mcmahanbenl.co.uk  893
# 4        http://www.champagneroom.co.uk  757

# %%
# Select rows with index values 'Andrade' and 'Veness', with all columns between 'city' and 'email'
data['first_name']
# Select same rows, with just 'first_name', 'address' and 'city' columns
#data.loc['Andrade':'Veness', ['first_name', 'address', 'city']]
 
# Change the index to be based on the 'id' column
data.set_index('id', inplace=True)
# select the row with 'id' = 487
#data.loc[487]
# Out:
# id
# 720      Aleshia
# 502         Evan
# 929       France
# 893      Ulysses
# 757       Tyisha
#          ...
# 324        Avery
# 709         Reid
# 294    Charlette
# 846    Celestina
# 915           Mi
# Name: first_name, Length: 500, dtype: object

# %%
data.loc[:,['first_name','email']]
# Out:
#     first_name                       email
# id
# 720    Aleshia     atomkiewicz@hotmail.com
# 502       Evan    evan.zigomalas@gmail.com
# 929     France  france.andrade@hotmail.com
# 893    Ulysses         ulysses@hotmail.com
# 757     Tyisha   tyisha.veness@hotmail.com
# ..         ...                         ...
# 324      Avery            avery@veit.co.uk
# 709       Reid      reuresti@euresti.co.uk
# 294  Charlette    cbrenning@brenning.co.uk
# 846  Celestina   celestina_keeny@gmail.com
# 915         Mi              mi@hotmail.com
#
# [500 rows x 2 columns]

# %%
data.iloc[0:2, 0:3]
# Out:
#     first_name   last_name             company_name
# id
# 720    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc
# 502       Evan   Zigomalas       Cap Gemini America

# %% [markdown]
# ## EDA
# - Mainly there are three steps
# - 1 -Understanding
# - 2 -Cleaning
# - 3- Relationship between data
#
# # Importing Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## Faostats data

# %%
fstat=pd.read_csv(r'C:\Users\Blue\Desktop\New folder (3)\FAOSTAT_data_1-14-2022.csv')
fstat.head()
# Out:
#   Domain Code                        Domain  Area Code (FAO)         Area  \
# 0         TCL  Crops and livestock products                2  Afghanistan
# 1         TCL  Crops and livestock products                2  Afghanistan
# 2         TCL  Crops and livestock products                2  Afghanistan
# 3         TCL  Crops and livestock products                2  Afghanistan
# 4         TCL  Crops and livestock products                2  Afghanistan
#
#    Element Code          Element  Item Code (FAO)                      Item  \
# 0          5910  Export Quantity              862  Alfalfa meal and pellets
# 1          5910  Export Quantity              862  Alfalfa meal and pellets
# 2          5922     Export Value              862  Alfalfa meal and pellets
# 3          5922     Export Value              862  Alfalfa meal and pellets
# 4          5610  Import Quantity              231           Almonds shelled
#
#    Year Code  Year      Unit  Value Flag  \
# 0       2019  2019    tonnes   49.0    *
# 1       2020  2020    tonnes   21.0    *
# 2       2019  2019  1000 US$   18.0    *
# 3       2020  2020  1000 US$    8.0    *
# 4       2016  2016    tonnes  845.0    R
#
#                                  Flag Description
# 0                               Unofficial figure
# 1                               Unofficial figure
# 2                               Unofficial figure
# 3                               Unofficial figure
# 4  Estimated data using trading partners database

# %%
fs=fstat
fs.info
# Out:
# <bound method DataFrame.info of      Domain Code                        Domain  Area Code (FAO)         Area  \
# 0            TCL  Crops and livestock products                2  Afghanistan
# 1            TCL  Crops and livestock products                2  Afghanistan
# 2            TCL  Crops and livestock products                2  Afghanistan
# 3            TCL  Crops and livestock products                2  Afghanistan
# 4            TCL  Crops and livestock products                2  Afghanistan
# ...          ...                           ...              ...          ...
# 4564         TCL  Crops and livestock products                2  Afghanistan
# 4565         TCL  Crops and livestock products                2  Afghanistan
# 4566         TCL  Crops and livestock products                2  Afghanistan
# 4567         TCL  Crops and livestock products                2  Afghanistan
# 4568         TCL  Crops and livestock products                2  Afghanistan
#
#       Element Code          Element  Item Code (FAO)  \
# 0             5910  Export Quantity              862
# 1             5910  Export Quantity              862
# 2             5922     Export Value              862
# 3             5922     Export Value              862
# 4             5610  Import Quantity              231
# ...            ...              ...              ...
# 4564          5910  Export Quantity              892
# 4565          5922     Export Value              892
# 4566          5922     Export Value              892
# 4567          5922     Export Value              892
# 4568          5922     Export Value              892
#
#                               Item  Year Code  Year      Unit  Value Flag  \
# 0         Alfalfa meal and pellets       2019  2019    tonnes   49.0    *
# 1         Alfalfa meal and pellets       2020  2020    tonnes   21.0    *
# 2         Alfalfa meal and pellets       2019  2019  1000 US$   18.0    *
# 3         Alfalfa meal and pellets       2020  2020  1000 US$    8.0    *
# 4                  Almonds shelled       2016  2016    tonnes  845.0    R
# ...                            ...        ...   ...       ...    ...  ...
# 4564  Yoghurt, concentrated or not       2019  2019    tonnes   20.0    R
# 4565  Yoghurt, concentrated or not       2016  2016  1000 US$    3.0    R
# 4566  Yoghurt, concentrated or not       2017  2017  1000 US$   57.0  NaN
# 4567  Yoghurt, concentrated or not       2018  2018  1000 US$   57.0    R
# 4568  Yoghurt, concentrated or not       2019  2019  1000 US$   41.0    R
#
#                                     Flag Description
# 0                                  Unofficial figure
# 1                                  Unofficial figure
# 2                                  Unofficial figure
# 3                                  Unofficial figure
# 4     Estimated data using trading partners database
# ...                                              ...
# 4564  Estimated data using trading partners database
# 4565  Estimated data using trading partners database
# 4566                                   Official data
# 4567  Estimated data using trading partners database
# 4568  Estimated data using trading partners database
#
# [4569 rows x 14 columns]>

# %%
fs.shape
# Out:
# (4569, 14)

# %%
fs.describe()
# Out:
#        Area Code (FAO)  Element Code  Item Code (FAO)    Year Code  \
# count           4569.0   4569.000000      4569.000000  4569.000000
# mean               2.0   5729.475815       533.814839  2018.001313
# std                0.0    145.644763       330.709656     1.416688
# min                2.0   5607.000000        15.000000  2016.000000
# 25%                2.0   5610.000000       247.000000  2017.000000
# 50%                2.0   5622.000000       515.000000  2018.000000
# 75%                2.0   5910.000000       767.000000  2019.000000
# max                2.0   5922.000000      1296.000000  2020.000000
#
#               Year         Value
# count  4569.000000  3.909000e+03
# mean   2018.001313  1.415627e+04
# std       1.416688  9.515146e+04
# min    2016.000000  0.000000e+00
# 25%    2017.000000  8.000000e+00
# 50%    2018.000000  1.480000e+02
# 75%    2019.000000  2.514000e+03
# max    2020.000000  2.273029e+06

# %%
fs.nunique()
# Out:
# Domain Code            1
# Domain                 1
# Area Code (FAO)        1
# Area                   1
# Element Code           9
# Element                4
# Item Code (FAO)      349
# Item                 349
# Year Code              5
# Year                   5
# Unit                   5
# Value               1780
# Flag                   6
# Flag Description       7
# dtype: int64

# %%
fs.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code (FAO)', 'Area', 'Element Code',
#        'Element', 'Item Code (FAO)', 'Item', 'Year Code', 'Year', 'Unit',
#        'Value', 'Flag', 'Flag Description'],
#       dtype='object')

# %%
fs['Item'].unique()
# Out:
# array(['Alfalfa meal and pellets', 'Almonds shelled',
#        'Almonds, with shell', 'Animals live nes',
#        'Anise, badian, fennel, coriander', 'Apples', 'Apricots',
#        'Apricots, dry', 'Areca nuts', 'Artichokes', 'Asparagus',
#        'Avocados', 'Bacon and ham', 'Bambara beans', 'Bananas', 'Barley',
#        'Beans, dry', 'Beans, green', 'Beehives', 'Beer of barley',
#        'Beeswax', 'Beverages, distilled alcoholic',
#        'Beverages, fermented rice', 'Beverages, non alcoholic',
#        'Blueberries', 'Bran, maize', 'Bran, sorghum', 'Bran, wheat',
#        'Brazil nuts, shelled', 'Bread', 'Broad beans, horse beans, dry',
#        'Buckwheat', 'Buffaloes', 'Butter, cow milk',
#        'Buttermilk, curdled, acidified milk',
#        'Cabbages and other brassicas', 'Cake, copra', 'Cake, cottonseed',
#        'Cake, groundnuts', 'Cake, linseed', 'Cake, rapeseed',
#        'Cake, soybeans', 'Cake, sunflower', 'Camels', 'Canary seed',
#        'Carrots and turnips', 'Cashew nuts, shelled',
#        'Cashew nuts, with shell', 'Cassava dried', 'Cattle',
#        'Cauliflowers and broccoli', 'Cereal preparations nes',
#        'Cereals, breakfast', 'Cheese, processed',
#        'Cheese, whole cow milk', 'Cherries', 'Cherries, sour', 'Chestnut',
#        'Chick peas', 'Chickens', 'Chillies and peppers, dry',
#        'Chillies and peppers, green', 'Chocolate products nes',
#        'Cider etc', 'Cigarettes', 'Cigars, cheroots',
#        'Cinnamon (cannella)', 'Cloves', 'Cocoa, beans', 'Cocoa, butter',
#        'Cocoa, powder & cake', 'Coconuts', 'Coconuts, desiccated',
#        'Cocoons, unreelable & waste', 'Coffee, extracts', 'Coffee, green',
#        'Coffee, husks and skins', 'Coffee, roasted',
#        'Coffee, substitutes containing coffee', 'Copra', 'Cotton lint',
#        'Cotton linter', 'Cotton waste', 'Cotton, carded, combed',
#        'Cottonseed', 'Cream fresh', 'Crude materials',
#        'Cucumbers and gherkins', 'Currants', 'Dates', 'Ducks',
#        'Eggplants (aubergines)', 'Eggs, dried', 'Eggs, hen, in shell',
#        'Eggs, liquid', 'Eggs, other bird, in shell', 'Fat nes, prepared',
#        'Fat, cattle', 'Fat, liver prepared (foie gras)', 'Fatty acids',
#        'Fatty substance residues', 'Feed and meal, gluten',
#        'Feed supplements', 'Feed, compound nes', 'Feed, pulp of fruit',
#        'Feed, vegetable products nes', 'Fibre crops nes', 'Figs',
#        'Figs dried', 'Flax fibre and tow', 'Flour, cassava',
#        'Flour, cereals', 'Flour, maize', 'Flour, mixed grain',
#        'Flour, mustard', 'Flour, potatoes', 'Flour, pulses',
#        'Flour, rice', 'Flour, roots and tubers nes', 'Flour, wheat',
#        'Food prep nes', 'Food preparations, flour, malt extract',
#        'Food wastes', 'Forage products', 'Fructose and syrup, other',
#        'Fruit, cooked, homogenized preparations', 'Fruit, dried nes',
#        'Fruit, fresh nes', 'Fruit, prepared nes',
#        'Fruit, tropical fresh nes', 'Garlic', 'Ginger',
#        'Glucose and dextrose', 'Goats', 'Gooseberries',
#        'Grapefruit (inc. pomelos)', 'Grapes', 'Grease incl. lanolin wool',
#        'Groundnuts, prepared', 'Groundnuts, shelled', 'Hair, fine',
#        'Hazelnuts, shelled', 'Hazelnuts, with shell', 'Hides nes',
#        'Hides, cattle, wet salted', 'Honey, natural', 'Hops', 'Horses',
#        'Ice cream and edible ice', 'Infant food',
#        'Juice, apple, concentrated', 'Juice, apple, single strength',
#        'Juice, citrus, concentrated', 'Juice, citrus, single strength',
#        'Juice, fruit nes', 'Juice, grape', 'Juice, grapefruit',
#        'Juice, grapefruit, concentrated', 'Juice, lemon, single strength',
#        'Juice, orange, concentrated', 'Juice, orange, single strength',
#        'Juice, pineapple', 'Juice, pineapple, concentrated',
#        'Juice, tomato', 'Jute', 'Kiwi fruit', 'Kola nuts', 'Lactose',
#        'Lard', 'Leeks, other alliaceous vegetables', 'Lemons and limes',
#        'Lentils', 'Lettuce and chicory', 'Linseed', 'Macaroni', 'Maize',
#        'Malt', 'Mangoes, mangosteens, guavas', 'Maple sugar and syrups',
#        'Margarine, liquid', 'Margarine, short', 'Mat?', 'Meal, meat',
#        'Meat nes', 'Meat, beef and veal sausages',
#        'Meat, beef, preparations', 'Meat, cattle',
#        'Meat, cattle, boneless (beef & veal)', 'Meat, chicken',
#        'Meat, chicken, canned', 'Meat, dried nes', 'Meat, duck',
#        'Meat, game', 'Meat, goat', 'Meat, goose and guinea fowl',
#        'Meat, pig', 'Meat, pig sausages', 'Meat, pig, preparations',
#        'Meat, pork', 'Meat, rabbit', 'Meat, sheep', 'Meat, turkey',
#        'Melons, other (inc.cantaloupes)',
#        'Milk, products of natural constituents nes', 'Milk, skimmed cow',
#        'Milk, skimmed dried', 'Milk, whole condensed',
#        'Milk, whole dried', 'Milk, whole evaporated',
#        'Milk, whole fresh cow', 'Millet', 'Mixes and doughs', 'Molasses',
#        'Mules', 'Mushrooms and truffles', 'Mushrooms, canned',
#        'Mustard seed', 'Nutmeg, mace and cardamoms', 'Nuts nes',
#        'Nuts, prepared (exc. groundnuts)', 'Oats', 'Oats rolled',
#        'Offals, edible, cattle', 'Offals, liver chicken',
#        'Offals, pigs, edible', 'Offals, sheep,edible', 'Oil, boiled etc',
#        'Oil, castor beans', 'Oil, citronella', 'Oil, coconut (copra)',
#        'Oil, cottonseed', 'Oil, essential nes', 'Oil, groundnut',
#        'Oil, linseed', 'Oil, maize', 'Oil, olive residues',
#        'Oil, olive, virgin', 'Oil, palm', 'Oil, palm kernel',
#        'Oil, rapeseed', 'Oil, sesame', 'Oil, soybean', 'Oil, sunflower',
#        'Oil, vegetable origin nes', 'Oils, fats of animal nes',
#        'Oilseeds nes', 'Olives', 'Olives preserved', 'Onions, dry',
#        'Onions, shallots, green', 'Oranges', 'Papayas', 'Pastry',
#        'Peaches and nectarines', 'Peanut butter', 'Pears', 'Peas, dry',
#        'Peas, green', 'Pepper (piper spp.)', 'Peppermint', 'Persimmons',
#        'Pet food', 'Pigs', 'Pineapples', 'Pineapples canned',
#        'Pistachios', 'Plantains and others', 'Plums and sloes',
#        'Plums dried (prunes)', 'Poppy seed', 'Potatoes',
#        'Potatoes, frozen', 'Pumpkins, squash and gourds',
#        'Pyrethrum, dried', 'Pyrethrum, extraction', 'Quinces', 'Quinoa',
#        'Raisins', 'Rapeseed', 'Rice, broken', 'Rice, husked',
#        'Rice, milled', 'Rice, milled/husked', 'Rice, paddy',
#        'Rice, paddy (rice milled equivalent)', 'Rodents, other',
#        'Roots and tubers nes', 'Rubber natural dry', 'Rubber, natural',
#        'Rye', 'Sesame seed', 'Sheep', 'Silk, raw',
#        'Silk-worm cocoons, reelable', 'Skins, calve, wet salted',
#        'Skins, sheep, dry salted', 'Skins, sheep, with wool', 'Sorghum',
#        'Soya sauce', 'Soybeans', 'Spices nes', 'Spinach', 'Straw husks',
#        'Strawberries', 'Sugar beet', 'Sugar confectionery',
#        'Sugar crops nes', 'Sugar nes', 'Sugar Raw Centrifugal',
#        'Sugar refined', 'Sunflower seed', 'Sweet corn frozen',
#        'Sweet corn prep or preserved', 'Sweet potatoes', 'Tallow',
#        'Tangerines, mandarins, clementines, satsumas', 'Tea',
#        'Tea, mate extracts', 'Tobacco products nes',
#        'Tobacco, unmanufactured', 'Tomatoes', 'Tomatoes, paste',
#        'Tomatoes, peeled', 'Vanilla', 'Vegetables in vinegar',
#        'Vegetables, dehydrated', 'Vegetables, fresh nes',
#        'Vegetables, fresh or dried products nes', 'Vegetables, frozen',
#        'Vegetables, homogenized preparations',
#        'Vegetables, preserved nes', 'Vegetables, preserved, frozen',
#        'Vegetables, temporarily preserved', 'Vermouths & similar',
#        'Wafers', 'Walnuts, shelled', 'Walnuts, with shell', 'Watermelons',
#        'Waters,ice etc', 'Waxes vegetable', 'Wheat', 'Whey, condensed',
#        'Whey, dry', 'Wine', 'Wool, degreased', 'Wool, greasy',
#        'Wool, hair waste', 'Yoghurt', 'Yoghurt, concentrated or not'],
#       dtype=object)

# %%
fs["Item"].append([fs["Area"]]).nunique()
#Or
fs[['Item',"Area","Element"]].nunique
# Out:
# <bound method DataFrame.nunique of                               Item         Area          Element
# 0         Alfalfa meal and pellets  Afghanistan  Export Quantity
# 1         Alfalfa meal and pellets  Afghanistan  Export Quantity
# 2         Alfalfa meal and pellets  Afghanistan     Export Value
# 3         Alfalfa meal and pellets  Afghanistan     Export Value
# 4                  Almonds shelled  Afghanistan  Import Quantity
# ...                            ...          ...              ...
# 4564  Yoghurt, concentrated or not  Afghanistan  Export Quantity
# 4565  Yoghurt, concentrated or not  Afghanistan     Export Value
# 4566  Yoghurt, concentrated or not  Afghanistan     Export Value
# 4567  Yoghurt, concentrated or not  Afghanistan     Export Value
# 4568  Yoghurt, concentrated or not  Afghanistan     Export Value
#
# [4569 rows x 3 columns]>

# %%
#find null values
fs.isnull().sum()
# Out:
# Domain Code           0
# Domain                0
# Area Code (FAO)       0
# Area                  0
# Element Code          0
# Element               0
# Item Code (FAO)       0
# Item                  0
# Year Code             0
# Year                  0
# Unit                  0
# Value               660
# Flag                920
# Flag Description      0
# dtype: int64

# %%
#droping the flag  assign to a new clean variable
fs_clean=fs.drop(['Flag'],axis=1)

# %%
fs_clean.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code (FAO)', 'Area', 'Element Code',
#        'Element', 'Item Code (FAO)', 'Item', 'Year Code', 'Year', 'Unit',
#        'Value', 'Flag Description'],
#       dtype='object')

# %%
fs_clean.isnull().sum()
# Out:
# Domain Code           0
# Domain                0
# Area Code (FAO)       0
# Area                  0
# Element Code          0
# Element               0
# Item Code (FAO)       0
# Item                  0
# Year Code             0
# Year                  0
# Unit                  0
# Value               660
# Flag Description      0
# dtype: int64

# %%
fs_clean.shape
# Out:
# (4569, 13)

# %%
fs_clean=fs_clean.dropna()

# %%
fs_clean.isnull()
# Out:
#       Domain Code  Domain  Area Code (FAO)   Area  Element Code  Element  \
# 0           False   False            False  False         False    False
# 1           False   False            False  False         False    False
# 2           False   False            False  False         False    False
# 3           False   False            False  False         False    False
# 4           False   False            False  False         False    False
# ...           ...     ...              ...    ...           ...      ...
# 4564        False   False            False  False         False    False
# 4565        False   False            False  False         False    False
# 4566        False   False            False  False         False    False
# 4567        False   False            False  False         False    False
# 4568        False   False            False  False         False    False
#
#       Item Code (FAO)   Item  Year Code   Year   Unit  Value  Flag Description
# 0               False  False      False  False  False  False             False
# 1               False  False      False  False  False  False             False
# 2               False  False      False  False  False  False             False
# 3               False  False      False  False  False  False             False
# 4               False  False      False  False  False  False             False
# ...               ...    ...        ...    ...    ...    ...               ...
# 4564            False  False      False  False  False  False             False
# 4565            False  False      False  False  False  False             False
# 4566            False  False      False  False  False  False             False
# 4567            False  False      False  False  False  False             False
# 4568            False  False      False  False  False  False             False
#
# [3909 rows x 13 columns]

# %%
fs_clean.shape
# Out:
# (3909, 13)

# %%
fs_clean.value_counts()
# Out:
# Domain Code  Domain                        Area Code (FAO)  Area         Element Code  Element          Item Code (FAO)  Item                  Year Code  Year  Unit      Value      Flag Description
# TCL          Crops and livestock products  2                Afghanistan  5607          Import Quantity  1181             Beehives              2016       2016  No        1184862.0  Estimated data using trading partners database    1
#                                                                          5910          Export Quantity  230              Cashew nuts, shelled  2018       2018  tonnes    3.0        Estimated data using trading partners database    1
#                                                                                                         231              Almonds shelled       2016       2016  tonnes    1691.0     Estimated data using trading partners database    1
#                                                                                                                                                2017       2017  tonnes    3335.0     Estimated data using trading partners database    1
#                                                                                                                                                2018       2018  tonnes    3339.0     Estimated data using trading partners database    1
#                                                                                                                                                                                                                                       ..
#                                                                          5622          Import Value     75               Oats                  2016       2016  1000 US$  10.0       Estimated data using trading partners database    1
#                                                                                                                                                2018       2018  1000 US$  482.0      Estimated data using trading partners database    1
#                                                                                                                                                2019       2019  1000 US$  1205.0     Estimated data using trading partners database    1
#                                                                                                                                                2020       2020  1000 US$  1037.0     Estimated data using trading partners database    1
#                                                                          5922          Export Value     1293             Crude materials       2020       2020  1000 US$  20152.0    Estimated data using trading partners database    1
# Length: 3909, dtype: int64

# %%
fs_clean['Item'].value_counts()
# Out:
# Sheep                        21
# Horses                       21
# Olives preserved             20
# Peaches and nectarines       20
# Grapes                       20
#                              ..
# Feed and meal, gluten         2
# Flour, cassava                2
# Pyrethrum, extraction         2
# Beverages, fermented rice     2
# Buffaloes                     1
# Name: Item, Length: 347, dtype: int64

# %%
fs.describe()
# Out:
#        Area Code (FAO)  Element Code  Item Code (FAO)    Year Code  \
# count           4569.0   4569.000000      4569.000000  4569.000000
# mean               2.0   5729.475815       533.814839  2018.001313
# std                0.0    145.644763       330.709656     1.416688
# min                2.0   5607.000000        15.000000  2016.000000
# 25%                2.0   5610.000000       247.000000  2017.000000
# 50%                2.0   5622.000000       515.000000  2018.000000
# 75%                2.0   5910.000000       767.000000  2019.000000
# max                2.0   5922.000000      1296.000000  2020.000000
#
#               Year         Value
# count  4569.000000  3.909000e+03
# mean   2018.001313  1.415627e+04
# std       1.416688  9.515146e+04
# min    2016.000000  0.000000e+00
# 25%    2017.000000  8.000000e+00
# 50%    2018.000000  1.480000e+02
# 75%    2019.000000  2.514000e+03
# max    2020.000000  2.273029e+06

# %%
#describe the clean data 
fs_clean.describe()
# Out:
#        Area Code (FAO)  Element Code  Item Code (FAO)    Year Code  \
# count           3909.0   3909.000000      3909.000000  3909.000000
# mean               2.0   5729.210284       534.080839  2018.130980
# std                0.0    145.574777       328.469000     1.465479
# min                2.0   5607.000000        15.000000  2016.000000
# 25%                2.0   5610.000000       249.000000  2017.000000
# 50%                2.0   5622.000000       515.000000  2018.000000
# 75%                2.0   5910.000000       754.000000  2019.000000
# max                2.0   5922.000000      1296.000000  2020.000000
#
#               Year         Value
# count  3909.000000  3.909000e+03
# mean   2018.130980  1.415627e+04
# std       1.465479  9.515146e+04
# min    2016.000000  0.000000e+00
# 25%    2017.000000  8.000000e+00
# 50%    2018.000000  1.480000e+02
# 75%    2019.000000  2.514000e+03
# max    2020.000000  2.273029e+06

# %% [markdown]
# ## Outliers
# - Show with example using boxplot

# %%
fs_clean.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code (FAO)', 'Area', 'Element Code',
#        'Element', 'Item Code (FAO)', 'Item', 'Year Code', 'Year', 'Unit',
#        'Value', 'Flag Description'],
#       dtype='object')

# %%
sns.boxplot(x='Element',y='Value',data=fs_clean)
# Out:
# <AxesSubplot:xlabel='Element', ylabel='Value'>

# %%
#displot
sns.displot(fs_clean['Element'])

# %%
fs_clean['Value']
# Out:
# 0        49.0
# 1        21.0
# 2        18.0
# 3         8.0
# 4       845.0
#         ...
# 4564     20.0
# 4565      3.0
# 4566     57.0
# 4567     57.0
# 4568     41.0
# Name: Value, Length: 3909, dtype: float64

# %%
fsc=fs_clean[fs_clean['Value']>132500]
fsc.shape
# Out:
# (78, 13)

# %%
#removing outliers
sns.boxplot(x='Element',y='Value',data=fsc)
# Out:
# <AxesSubplot:xlabel='Element', ylabel='Value'>

# %%
sns.displot(fsc['Value'])

# %%
fssc=fs_clean[fs_clean['Item']<"20"]
fssc["Item"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of Series([], Name: Item, dtype: object)>

# %%
fs_clean.nunique()
# Out:
# Domain Code            1
# Domain                 1
# Area Code (FAO)        1
# Area                   1
# Element Code           9
# Element                4
# Item Code (FAO)      347
# Item                 347
# Year Code              5
# Year                   5
# Unit                   5
# Value               1780
# Flag Description       6
# dtype: int64

# %% [markdown]
# # Correlation
# Correlation refers to the statistical relationship between two entities. In other words, it's how two variables move in relation to one another. Correlation can be used for various data sets, as well. In some cases, you might have predicted how things will correlate, while in others, the relationship will be a surprise to you. It's important to understand that correlation does not mean the relationship is causal.
#
# To understand how correlation works, it's important to understand the following terms:
#
# - Positive correlation: A positive correlation would be 1. This means the two variables moved either up or down in the same direction together.
# - Negative correlation: A negative correlation is -1. This means the two variables moved in opposite directions.
# - Zero or no correlation: A correlation of zero means there is no relationship between the two variables. In other words, as one variable moves one way, the other moved in another unrelated direction.

# %%
fsc.corr()
# Out:
#                  Area Code (FAO)  Element Code  Item Code (FAO)  Year Code  \
# Area Code (FAO)              NaN           NaN              NaN        NaN
# Element Code                 NaN      1.000000         0.385720   0.180473
# Item Code (FAO)              NaN      0.385720         1.000000   0.095097
# Year Code                    NaN      0.180473         0.095097   1.000000
# Year                         NaN      0.180473         0.095097   1.000000
# Value                        NaN     -0.165362         0.053954  -0.019244
#
#                      Year     Value
# Area Code (FAO)       NaN       NaN
# Element Code     0.180473 -0.165362
# Item Code (FAO)  0.095097  0.053954
# Year Code        1.000000 -0.019244
# Year             1.000000 -0.019244
# Value           -0.019244  1.000000

# %%
corr_fsc=fsc.corr()

# %%
sns.heatmap(corr_fsc)
# Out:
# <AxesSubplot:>

# %%
#to show relation in numeric form 
sns.heatmap(corr_fsc, annot=True)
# Out:
# <AxesSubplot:>

# %%
#relplot
sns.relplot(x="Value", y="Element Code", hue='Element',data=fsc)

# %%
sns.catplot(x="Value", y="Element Code", hue='Element',data=fsc)

# %%
sns.catplot(x="Element Code", y="Value", hue='Element',data=fsc, kind='bar')

# %%
sns.catplot(x="Element Code", y="Value", hue='Element',data=fsc, kind='box')

# %%
fs_clean.nunique()
# Out:
# Domain Code            1
# Domain                 1
# Area Code (FAO)        1
# Area                   1
# Element Code           9
# Element                4
# Item Code (FAO)      347
# Item                 347
# Year Code              5
# Year                   5
# Unit                   5
# Value               1780
# Flag Description       6
# dtype: int64

# %%
fsc.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Area Code (FAO)'}>,
#         <AxesSubplot:title={'center':'Element Code'}>],
#        [<AxesSubplot:title={'center':'Item Code (FAO)'}>,
#         <AxesSubplot:title={'center':'Year Code'}>],
#        [<AxesSubplot:title={'center':'Year'}>,
#         <AxesSubplot:title={'center':'Value'}>]], dtype=object)

# %%
sns.distplot(fsc['Year'])
# Out:
# C:\Users\Blue\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Year', ylabel='Density'>

# %% [markdown]
# ## Log Transfermation
# - The log transformation can be used to make highly skewed distributions less skewed. This can be valuable both for making patterns in the data more interpretable and for helping to meet the assumptions of inferential statistics.

# %%
fsc["Year log"]=np.log(fsc['Year'])
# Out:
# C:\Users\Blue\AppData\Local\Temp/ipykernel_8004/968251240.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fsc["Year log"]=np.log(fsc['Year'])

# %%
sns.boxplot(x='Year',y='Value',data=fsc)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Value'>

# %%
sns.boxplot(x='Year log',y='Value',data=fsc)
# Out:
# <AxesSubplot:xlabel='Year log', ylabel='Value'>

# %%
sns.boxplot(x='Element',y='Value',data=fsc)
# Out:
# <AxesSubplot:xlabel='Element', ylabel='Value'>

# %%
fsc["Value log"]=np.log(fsc['Value'])
# Out:
# C:\Users\Blue\AppData\Local\Temp/ipykernel_8004/2593499932.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fsc["Value log"]=np.log(fsc['Value'])

# %%
sns.boxplot(x='Element',y='Value log',data=fsc)
# Out:
# <AxesSubplot:xlabel='Element', ylabel='Value log'>

# %% [markdown]
# After log transfermation we can see that all most all theoutliers have been removed.

# %% [markdown]
# # Data wrangling
#
# - Process of transforming and mapping data from one "raw" data form into another format with the intent of making it more appropriate and valuable for a variety of downstream purposes such as analytics
# - The steps that convert data from its raw form to the tidy form is called data wrangling. This process is a critical step for any data scientist. Knowing how to wrangle and clean data will enable you to make critical insights that would otherwise be hidden.
#
# ## Let's begain with a case study

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 

kashti= sns.load_dataset("titanic")
kashti.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
ks1= kashti
ks2=kashti
ks=kashti

# %%
#single coulum operation
(kashti['age']+12).head()
# Out:
# 0    34.0
# 1    50.0
# 2    38.0
# 3    47.0
# 4    47.0
# Name: age, dtype: float64

# %%
(kashti['age']*12).head()
# Out:
# 0    264.0
# 1    456.0
# 2    312.0
# 3    420.0
# 4    420.0
# Name: age, dtype: float64

# %% [markdown]
# > Dealing missing values
#
# > nan, 0 or blank cell
#
# > replace by mean
#
# > frequency or mode
#
# > other function based on sampler( jis ny kia ho wahi hi krskta hy )
#
# > ML algo  like regression etc
#
# > leave it like it

# %%
# to find all the missing values 
kashti.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# remove missing values 
kashti.dropna(subset=['deck'], axis=0, inplace=True)

# %%
kashti.isnull().sum()
# Out:
# survived        0
# pclass          0
# sex             0
# age            19
# sibsp           0
# parch           0
# fare            0
# embarked        2
# class           0
# who             0
# adult_male      0
# deck            0
# embark_town     2
# alive           0
# alone           0
# dtype: int64

# %%
#remove the whole missing values  from dataframe 
ks=ks.dropna()

# %%
ks.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
ks.shape
# Out:
# (182, 15)

# %%
ks1.isnull().sum()
# Out:
# survived        0
# pclass          0
# sex             0
# age            19
# sibsp           0
# parch           0
# fare            0
# embarked        2
# class           0
# who             0
# adult_male      0
# deck            0
# embark_town     2
# alive           0
# alone           0
# dtype: int64

# %%
#replacing by mean
mean=ks1['age'].mean()
mean
# Out:
# 35.77945652173913

# %%
mean1=kashti['age'].mean()
mean
# Out:
# 35.77945652173913

# %%
kashti['age']=kashti['age'].replace(np.nan,mean)
kashti.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
ks1['age']=ks1['age'].replace(np.nan,mean)

# %%
ks1.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
# Removing embark_town values
kashti.dropna(subset=['embark_town'], axis=0, inplace=True)

# %%
kashti.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
kashti.dropna(subset=['deck'], axis=0, inplace=True)

# %%
kashti.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# # Data formatting (Standarization)
# - single standard
# - understandable
# - easy to gather
# - easy to work

# %%
# formatting 
# data types of the whole set 
kashti.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
#converting data types 
kashti['survived']=kashti['survived'].astype("float64")
kashti.dtypes
# Out:
# survived        float64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
kashti['survived']=kashti['survived'].astype("int64")
kashti.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# working with a single column
kashti['age']=kashti['age']*365
kashti.head(10)
# Out:
#     survived  pclass     sex          age  sibsp  parch      fare embarked  \
# 1          1       1  female  13870.00000      1      0   71.2833        C
# 3          1       1  female  12775.00000      1      0   53.1000        S
# 6          0       1    male  19710.00000      0      0   51.8625        S
# 10         1       3  female   1460.00000      1      1   16.7000        S
# 11         1       1  female  21170.00000      0      0   26.5500        S
# 21         1       2    male  12410.00000      0      0   13.0000        S
# 23         1       1    male  10220.00000      0      0   35.5000        S
# 27         0       1    male   6935.00000      3      2  263.0000        S
# 31         1       1  female  13059.50163      1      0  146.5208        C
# 52         1       1  female  17885.00000      1      0   76.7292        C
#
#      class    who  adult_male deck  embark_town alive  alone
# 1    First  woman       False    C    Cherbourg   yes  False
# 3    First  woman       False    C  Southampton   yes  False
# 6    First    man        True    E  Southampton    no   True
# 10   Third  child       False    G  Southampton   yes  False
# 11   First  woman       False    C  Southampton   yes   True
# 21  Second    man        True    D  Southampton   yes   True
# 23   First    man        True    A  Southampton   yes   True
# 27   First    man        True    C  Southampton    no  False
# 31   First  woman       False    B    Cherbourg   yes  False
# 52   First  woman       False    D    Cherbourg   yes  False

# %%
# Always rename after changing the world 
kashti.rename(columns={'age': 'age in days'}, inplace=True)
kashti.head(10)
# Out:
#     survived  pclass     sex  age in days  sibsp  parch      fare embarked  \
# 1          1       1  female  13870.00000      1      0   71.2833        C
# 3          1       1  female  12775.00000      1      0   53.1000        S
# 6          0       1    male  19710.00000      0      0   51.8625        S
# 10         1       3  female   1460.00000      1      1   16.7000        S
# 11         1       1  female  21170.00000      0      0   26.5500        S
# 21         1       2    male  12410.00000      0      0   13.0000        S
# 23         1       1    male  10220.00000      0      0   35.5000        S
# 27         0       1    male   6935.00000      3      2  263.0000        S
# 31         1       1  female  13059.50163      1      0  146.5208        C
# 52         1       1  female  17885.00000      1      0   76.7292        C
#
#      class    who  adult_male deck  embark_town alive  alone
# 1    First  woman       False    C    Cherbourg   yes  False
# 3    First  woman       False    C  Southampton   yes  False
# 6    First    man        True    E  Southampton    no   True
# 10   Third  child       False    G  Southampton   yes  False
# 11   First  woman       False    C  Southampton   yes   True
# 21  Second    man        True    D  Southampton   yes   True
# 23   First    man        True    A  Southampton   yes   True
# 27   First    man        True    C  Southampton    no  False
# 31   First  woman       False    B    Cherbourg   yes  False
# 52   First  woman       False    D    Cherbourg   yes  False

# %% [markdown]
# # Data Normalization
# - uniform data
# - same impact
# - bell curved uniform

# %%
#kashti
kashti.head(5)
# Out:
#     survived  pclass     sex  age in days  sibsp  parch     fare embarked  \
# 1          1       1  female      13870.0      1      0  71.2833        C
# 3          1       1  female      12775.0      1      0  53.1000        S
# 6          0       1    male      19710.0      0      0  51.8625        S
# 10         1       3  female       1460.0      1      1  16.7000        S
# 11         1       1  female      21170.0      0      0  26.5500        S
#
#     class    who  adult_male deck  embark_town alive  alone
# 1   First  woman       False    C    Cherbourg   yes  False
# 3   First  woman       False    C  Southampton   yes  False
# 6   First    man        True    E  Southampton    no   True
# 10  Third  child       False    G  Southampton   yes  False
# 11  First  woman       False    C  Southampton   yes   True

# %%
ks11= kashti[['age in days','fare']]
ks11.head(5)
# Out:
#     age in days     fare
# 1       13870.0  71.2833
# 3       12775.0  53.1000
# 6       19710.0  51.8625
# 10       1460.0  16.7000
# 11      21170.0  26.5500

# %%
# wide range data unable to plot in proper 
#methods of normalization 
#simple feature scaling 
ks11['fare']=ks11['fare']/ks11['fare'].max()
ks11['age in days']=ks11['age in days']/ks11['age in days'].max()
ks11.head(5)
# Out:
# C:\Users\Blue\AppData\Local\Temp/ipykernel_8004/4110347462.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks11['fare']=ks11['fare']/ks11['fare'].max()
# C:\Users\Blue\AppData\Local\Temp/ipykernel_8004/4110347462.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks11['age in days']=ks11['age in days']/ks11['age in days'].max()
#     age in days      fare
# 1        0.4750  0.139136
# 3        0.4375  0.103644
# 6        0.6750  0.101229
# 10       0.0500  0.032596
# 11       0.7250  0.051822

# %%
# Min - Max method 
ks11['fare']=(ks11['fare']-ks11['fare'].min())/ks11['fare'].max()-ks11['fare'].min()
ks11['age in days']=(ks11['age in days']-ks11['age in days'].min())/ks11['age in days'].max()-ks11['age in days'].min()
ks11.head(5)
# Out:
# C:\Users\Blue\AppData\Local\Temp/ipykernel_8004/833641576.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks11['fare']=(ks11['fare']-ks11['fare'].min())/ks11['fare'].max()-ks11['fare'].min()
# C:\Users\Blue\AppData\Local\Temp/ipykernel_8004/833641576.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks11['age in days']=(ks11['age in days']-ks11['age in days'].min())/ks11['age in days'].max()-ks11['age in days'].min()
#     age in days      fare
# 1        0.4520  0.139136
# 3        0.4145  0.103644
# 6        0.6520  0.101229
# 10       0.0270  0.032596
# 11       0.7020  0.051822

# %%
# Z score range -3 to 3
ks11['fare']=(ks11['fare']-ks11['fare'].mean())/ks11['fare'].std()
ks11['age in days']=(ks11['age in days']-ks11['age in days'].mean())/ks11['age in days'].std()
ks11.head()
# Out:
# C:\Users\Blue\AppData\Local\Temp/ipykernel_8004/202309087.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks11['fare']=(ks11['fare']-ks11['fare'].mean())/ks11['fare'].std()
# C:\Users\Blue\AppData\Local\Temp/ipykernel_8004/202309087.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks11['age in days']=(ks11['age in days']-ks11['age in days'].mean())/ks11['age in days'].std()
#     age in days      fare
# 1      0.158434 -0.067057
# 3     -0.042791 -0.309853
# 6      1.231632 -0.326377
# 10    -2.122112 -0.795891
# 11     1.499931 -0.664367

# %%
# log transformation 
ks11['fare']=np.log(ks11['fare'])
ks11['age in days']=np.log(ks11['age in days'])
ks11.head(5)
# Out:
# C:\Users\Blue\anaconda3\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\Blue\AppData\Local\Temp/ipykernel_8004/3222178439.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks11['fare']=np.log(ks11['fare'])
# C:\Users\Blue\AppData\Local\Temp/ipykernel_8004/3222178439.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks11['age in days']=np.log(ks11['age in days'])
#     age in days  fare
# 1     -1.842419   NaN
# 3           NaN   NaN
# 6      0.208340   NaN
# 10          NaN   NaN
# 11     0.405419   NaN

# %% [markdown]
# # Binnig
# - Grouping of values in to smaller number of values
# - converting numeric into catogries

# %%
bins=[0,2,5,10,14,17,30,60,100]
labels=['infant','toddler','youngchild','teenager','youngadult','adult','elders']

# %%
bins=[0,18,40,70]
labels=["kids",'young','elders']

# %%
#creating bins for ages
ks['Age Category']=pd.cut(ks['age'],bins,labels=labels)
# Out:
# C:\Users\Blue\AppData\Local\Temp/ipykernel_8004/3356921721.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ks['Age Category']=pd.cut(ks['age'],bins,labels=labels)

# %%
kashti.head(5)
# Out:
#     survived  pclass     sex  age in days  sibsp  parch     fare embarked  \
# 1          1       1  female      13870.0      1      0  71.2833        C
# 3          1       1  female      12775.0      1      0  53.1000        S
# 6          0       1    male      19710.0      0      0  51.8625        S
# 10         1       3  female       1460.0      1      1  16.7000        S
# 11         1       1  female      21170.0      0      0  26.5500        S
#
#     class    who  adult_male deck  embark_town alive  alone
# 1   First  woman       False    C    Cherbourg   yes  False
# 3   First  woman       False    C  Southampton   yes  False
# 6   First    man        True    E  Southampton    no   True
# 10  Third  child       False    G  Southampton   yes  False
# 11  First  woman       False    C  Southampton   yes   True

# %%
ks['Age Category'].value_counts()
# Out:
# young     95
# elders    62
# kids      23
# Name: Age Category, dtype: int64

# %%
ks['Age Category'].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Age Category'>

# %%
# Dummies variable 
# easy for computation 
# ( 0 , 1)
pd.get_dummies(ks1['sex'])
ks1.head(5)
# Out:
#     survived  pclass     sex  age in days  sibsp  parch     fare embarked  \
# 1          1       1  female      13870.0      1      0  71.2833        C
# 3          1       1  female      12775.0      1      0  53.1000        S
# 6          0       1    male      19710.0      0      0  51.8625        S
# 10         1       3  female       1460.0      1      1  16.7000        S
# 11         1       1  female      21170.0      0      0  26.5500        S
#
#     class    who  adult_male deck  embark_town alive  alone
# 1   First  woman       False    C    Cherbourg   yes  False
# 3   First  woman       False    C  Southampton   yes  False
# 6   First    man        True    E  Southampton    no   True
# 10  Third  child       False    G  Southampton   yes  False
# 11  First  woman       False    C  Southampton   yes   True

# %%
# INSERTING DUMMIES 
ks1 = pd.get_dummies(ks1, prefix= '', prefix_sep='', 
                            columns=['sex'])
ks1.head()
# Out:
#     survived  pclass  age in days  sibsp  parch     fare embarked  class  \
# 1          1       1      13870.0      1      0  71.2833        C  First
# 3          1       1      12775.0      1      0  53.1000        S  First
# 6          0       1      19710.0      0      0  51.8625        S  First
# 10         1       3       1460.0      1      1  16.7000        S  Third
# 11         1       1      21170.0      0      0  26.5500        S  First
#
#       who  adult_male deck  embark_town alive  alone  female  male
# 1   woman       False    C    Cherbourg   yes  False       1     0
# 3   woman       False    C  Southampton   yes  False       1     0
# 6     man        True    E  Southampton    no   True       0     1
# 10  child       False    G  Southampton   yes  False       1     0
# 11  woman       False    C  Southampton   yes   True       1     0

# %%
pd.get_dummies(ks1['who']).head(5)
# Out:
#     child  man  woman
# 1       0    0      1
# 3       0    0      1
# 6       0    1      0
# 10      1    0      0
# 11      0    0      1

# %%
ks1= pd.get_dummies(ks1, prefix= '', prefix_sep='', 
                            columns=['who'])

ks1.head(5)
# Out:
#     survived  pclass  age in days  sibsp  parch     fare embarked  class  \
# 1          1       1      13870.0      1      0  71.2833        C  First
# 3          1       1      12775.0      1      0  53.1000        S  First
# 6          0       1      19710.0      0      0  51.8625        S  First
# 10         1       3       1460.0      1      1  16.7000        S  Third
# 11         1       1      21170.0      0      0  26.5500        S  First
#
#     adult_male deck  embark_town alive  alone  female  male  child  man  woman
# 1        False    C    Cherbourg   yes  False       1     0      0    0      1
# 3        False    C  Southampton   yes  False       1     0      0    0      1
# 6         True    E  Southampton    no   True       0     1      0    1      0
# 10       False    G  Southampton   yes  False       1     0      1    0      0
# 11       False    C  Southampton   yes   True       1     0      0    0      1
